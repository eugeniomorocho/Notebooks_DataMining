# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Autor:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# # **Prueba práctica 3:**
# ## Ajuste de Hiperparámetros de una Red Neuronal para clasificación de Pinguinos de la Isla Palmer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Objetivo y alcance del trabajo:**

# %% [markdown]
# ### **Fase I:** Texto

# %% [markdown]
# ### **Fase II:** Fase II

# %% [markdown]
# ### **Fase III:** Fase III

# %% [markdown]
# ![image.png](attachment:image.png)
